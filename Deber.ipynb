# %%
import pandas as pd

# %%
Data_df=pd.read_csv("Data.csv")

# %%
Data_df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
Data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# ...

# %%
Data_df.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000  29069.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607      2.145894     66.558402     69.377533     68.418622
# std      288.747894      1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000      0.000000     10.000000      4.000000
# 25%      249.000000      1.000000     56.000000     59.000000     58.000000
# 50%      500.000000      2.000000     67.000000     70.000000     69.000000
# 75%      750.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %%
Data_df[((Data_df['Gender'] == 'female') & (Data_df['MathScore'] >= 80))].head()
# Out:
#     Unnamed: 0  Gender EthnicGroup          ParentEduc LunchType   TestPrep  \
# 2            2  female     group B     master's degree  standard       none
# 6            6  female     group B        some college  standard  completed
# 52          56  female     group E  associate's degree  standard  completed
# 86          94  female     group B        some college  standard       none
# 93         102  female     group D  associate's degree  standard       none
#
#    ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 2               single     sometimes          yes         4.0     school_bus
# 6              widowed         never           no         1.0        private
# 52             married     sometimes          yes         3.0     school_bus
# 86             married     regularly          yes         4.0        private
# 93             married     regularly          yes         3.0     school_bus
#
# ...

# %%
Data_df[((Data_df['NrSiblings'] >= 3.0) & (Data_df['PracticeSport'] == 'sometimes'))].head()
# Out:
#     Unnamed: 0  Gender EthnicGroup         ParentEduc     LunchType  \
# 2            2  female     group B    master's degree      standard
# 8            8    male     group D        high school  free/reduced
# 20          20    male     group D        high school      standard
# 26          26    male     group B       some college      standard
# 27          27  female     group C  bachelor's degree      standard
#
#      TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 2        none              single     sometimes          yes         4.0
# 8   completed              single     sometimes           no         3.0
# 20       none             married     sometimes          yes         5.0
# 26       none             married     sometimes          yes         5.0
# 27       none             married     sometimes          yes         4.0
#
#    TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...

# %%
Data_df[((Data_df['ParentEduc'] =='high school') & (Data_df['IsFirstChild'] == 'no'))].head()
# Out:
#     Unnamed: 0  Gender EthnicGroup   ParentEduc     LunchType   TestPrep  \
# 8            8    male     group D  high school  free/reduced  completed
# 12          12  female     group B  high school      standard       none
# 28          28    male     group C  high school      standard       none
# 83          91    male     group C  high school  free/reduced       none
# 84          92    male     group C  high school      standard       none
#
#    ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 8               single     sometimes           no         3.0        private
# 12             married     regularly           no         1.0        private
# 28             married     sometimes           no         1.0        private
# 83            divorced     regularly           no         4.0            NaN
# 84            divorced     sometimes           no         1.0            NaN
#
#    WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...

# %%
parent_marital_counts = Data_df['ParentMaritalStatus'].value_counts()
print("Cantidad de padres según el estado civil:\n", parent_marital_counts)
# Out:
# Cantidad de padres según el estado civil:
#  married     16844
# single       7097
# divorced     4919
# widowed       591
# Name: ParentMaritalStatus, dtype: int64

# %%
Gender_counts = Data_df['Gender'].value_counts()
print("Registros ingresados por genero:\n",Gender_counts)
# Out:
# Registros ingresados por genero:
#  female    15424
# male      15217
# Name: Gender, dtype: int64

# %%
Practiced_sport = len(Data_df[Data_df['PracticeSport']=='sometimes'])
print("Valor total de estudiantes que practican (a veces) deporte es:",Practiced_sport)
# Out:
# Valor total de estudiantes que practican (a veces) deporte es: 15213

# %%
Data_df[(Data_df['TestPrep']=='completed')&(Data_df['MathScore']>=50)].head()
# Out:
#     Unnamed: 0  Gender EthnicGroup    ParentEduc     LunchType   TestPrep  \
# 6            6  female     group B  some college      standard  completed
# 8            8    male     group D   high school  free/reduced  completed
# 13          13    male     group A  some college      standard  completed
# 21          21  female     group B  some college  free/reduced  completed
# 24          24    male     group D           NaN  free/reduced  completed
#
#    ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 6              widowed         never           no         1.0        private
# 8               single     sometimes           no         3.0        private
# 13              single     sometimes          yes         1.0        private
# 21             married     sometimes           no         2.0     school_bus
# 24             married     sometimes          yes         2.0     school_bus
#
#    WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...

# %%
Data_df[(Data_df['IsFirstChild']=='yes')&(Data_df['MathScore']>=90)].head()
# Out:
#      Unnamed: 0  Gender EthnicGroup         ParentEduc LunchType   TestPrep  \
# 33           34    male     group E       some college  standard       none
# 95          104    male         NaN       some college  standard  completed
# 105         114  female     group E  bachelor's degree  standard  completed
# 113         122  female     group C       some college  standard  completed
# 135         144    male     group D       some college  standard       none
#
#     ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 33             divorced     sometimes          yes         0.0     school_bus
# 95              married     regularly          yes         1.0     school_bus
# 105             married     regularly          yes         3.0     school_bus
# 113              single     regularly          yes         1.0            NaN
# 135            divorced     sometimes          yes         3.0        private
#
# ...

# %%
Data_df[(Data_df['ParentMaritalStatus']=='married')&(Data_df['MathScore']>=90)].head()
# Out:
#      Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 95          104    male         NaN        some college      standard
# 105         114  female     group E   bachelor's degree      standard
# 138         149    male     group E  associate's degree  free/reduced
# 153         165  female     group C   bachelor's degree      standard
# 158         171    male     group E    some high school      standard
#
#       TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 95   completed             married     regularly          yes         1.0
# 105  completed             married     regularly          yes         3.0
# 138  completed             married     regularly           no         3.0
# 153  completed             married     sometimes          yes         0.0
# 158       none             married     sometimes           no         3.0
#
#     TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...
